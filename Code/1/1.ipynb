# %%
import pandas as pd
import numpy as np
import os
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import pearsonr, spearmanr
from sklearn.metrics import mean_squared_error
import itertools
import time

def run_q1_analysis():
    #环境与路径设置
    DATA_PATH = '../../Data/0/男胎_预处理后数据.csv'
    RESULT_DIR = 'Result'
    os.makedirs(RESULT_DIR, exist_ok=True)

    log_path = os.path.join(RESULT_DIR, '文本_问题一_运行日志.txt')
    log_file = open(log_path, 'w', encoding='utf-8')

    #保存日志
    def log_and_print(message):
        print(message)
        log_file.write(f"{message}\n")

    #数据加载与预处理
    log_and_print("\n数据加载与预处理")
    
    male_df = pd.read_csv(DATA_PATH)

    # 向量化IQR离群值检测
    cols_to_check = ['Y染色体浓度', '孕周', '孕妇BMI']
    Q1 = male_df[cols_to_check].quantile(0.25)
    Q3 = male_df[cols_to_check].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    is_outlier = (male_df[cols_to_check] < lower_bound) | (male_df[cols_to_check] > upper_bound)
    final_clean_mask = ~is_outlier.any(axis=1)

    #创建最终建模数据集
    model_data = male_df[final_clean_mask].copy()
    model_data.rename(columns={'孕周': 'GW', '孕妇BMI': 'BMI'}, inplace=True)
    
    #剔除建模所需变量的任何剩余缺失值
    model_data.dropna(subset=['Y染色体浓度', 'GW', 'BMI', '孕妇代码'], inplace=True)

    log_and_print(f"原始数据 {len(male_df)}行。")
    log_and_print(f"剔除离群值和缺失值后，最终分析集共 {len(model_data)}行。")
    model_data.to_csv(os.path.join(RESULT_DIR, '表格_最终建模数据.csv'), index=False, encoding='utf-8-sig')

    #变量相关性分析
    log_and_print("\n开始变量相关性分析")
    
    corr_results = []
    for var in ['GW', 'BMI']:
        p_corr, p_pval = pearsonr(model_data['Y染色体浓度'], model_data[var])
        s_corr, s_pval = spearmanr(model_data['Y染色体浓度'], model_data[var])
        corr_results.append({
            '变量对': f'Y浓度 vs {var}', 
            '皮尔逊相关系数(r)': p_corr, 'Pearson P值': p_pval, 
            '斯皮尔曼相关系数(rho)': s_corr, 'Spearman P值': s_pval
        })
        
    df_corr = pd.DataFrame(corr_results)
    df_corr.to_csv(os.path.join(RESULT_DIR, '表格_相关性分析汇总.csv'), index=False, encoding='utf-8-sig', float_format='%.4f')
    log_and_print(df_corr.to_string())
    
    #模型筛选与拟合
    log_and_print("\n开始模型筛选与拟合")
    models = {}
    
    #M4（混合效应模型
    log_and_print("\n执行最优子集搜索")
    start_time = time.time()
    
    # 定义固定效应的候选预测因子
    predictors = ['GW', 'I(GW**2)', 'I(GW**3)', 'BMI', 'I(BMI**2)', 'I(BMI**3)', 'GW:BMI', 'I(GW**2):BMI', 'GW:I(BMI**2)']
    log_and_print(f"候选预测因子 ({len(predictors)}个): {predictors}")

    #使用OLS+BIC快速筛选
    best_models_by_size = {}
    for k in range(1, len(predictors) + 1):
        best_bic_k, best_formula_k = np.inf, None
        for combo in itertools.combinations(predictors, k):
            formula = f"Y染色体浓度 ~ {' + '.join(combo)}"
            try:
                ols_model = smf.ols(formula, data=model_data).fit()
                if ols_model.bic < best_bic_k:
                    best_bic_k, best_formula_k = ols_model.bic, formula
            except Exception:
                continue # 跳过无法拟合的模型组合
        if best_formula_k:
            best_models_by_size[k] = {'formula': best_formula_k, 'bic': best_bic_k}
            log_and_print(f"  - {k}个变量的最优组合BIC: {best_bic_k:.2f}")

    #使用LMM+BIC对优胜者进行精确拟合
    final_candidates = [v['formula'] for k, v in sorted(best_models_by_size.items())]
    best_lmm_model, best_lmm_bic, best_lmm_formula = None, np.inf, None

    for i, formula in enumerate(final_candidates):
        log_and_print(f"  - 测试候选模型 {i+1}/{len(final_candidates)}...")
        lmm_model = smf.mixedlm(formula, data=model_data, groups='孕妇代码').fit(reml=False, method='cg')
        if lmm_model.bic < best_lmm_bic:
            best_lmm_bic, best_lmm_model, best_lmm_formula = lmm_model.bic, lmm_model, formula
 
            
    models['M4_Mixed_Effect'] = best_lmm_model
    log_and_print("\n" + "="*50)
    log_and_print(f"M4最优子集搜索完成 (耗时: {time.time() - start_time:.2f} 秒)")
    log_and_print(f"最终M4固定效应公式: {best_lmm_formula}")
    log_and_print(f"M4的BIC值: {best_lmm_bic:.4f}")
    log_and_print("="*50)

    #基准模型拟合
    log_and_print("\nM1-M3: 拟合基准模型")
    models['M1_Linear'] = smf.ols('Y染色体浓度 ~ GW + BMI', data=model_data).fit()
    models['M2_Polynomial'] = smf.ols('Y染色体浓度 ~ GW + I(GW**2) + BMI', data=model_data).fit()

    data_for_m3 = model_data[model_data['Y染色体浓度'] > 0].copy()
    models['M3_Exponential_GLM'] = smf.glm('Y染色体浓度 ~ GW + BMI', data=data_for_m3, family=sm.families.Gamma(link=sm.families.links.log())).fit()
    log_and_print("M1, M2, M3 基准模型拟合完成。")

    #模型评估
    log_and_print("\n模型评估与结果产出")
    eval_results = []
    model_order = ['M1_Linear', 'M2_Polynomial', 'M3_Exponential_GLM', 'M4_Mixed_Effect']

    for name in model_order:
        model = models.get(name)
        if model is None: continue #如果M4未成功拟合则跳过

        #确定评估数据集
        current_data = data_for_m3 if 'GLM' in name else model_data
        y_true = current_data[model.model.endog_names]
        y_pred = model.predict(current_data) 
        
        #计算指标
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        
        #R方报告
        if hasattr(model, 'rsquared_adj'):
            r2_info = f"{model.rsquared_adj:.4f} (调整 R²)"
        elif 'Mixed' in name:
            #数据提取自训练日志
            r2_info = "边际:0.4197, 条件:0.9158"
        elif 'GLM' in name:
            pseudo_r2 = 1 - (model.llf / model.llnull)
            r2_info = f"{pseudo_r2:.4f} (伪 R²)"
        else:
            r2_info = "N/A"

        eval_results.append({
            '模型': name, '对数似然值': model.llf, 
            'AIC': model.aic, 'BIC': model.bic, 
            'RMSE': rmse, 'R方': r2_info
        })
        #保存各模型摘要
        with open(os.path.join(RESULT_DIR, f'文本_{name}_摘要.txt'), 'w', encoding='utf-8') as f:
            f.write(str(model.summary()))

    df_comparison = pd.DataFrame(eval_results)
    df_comparison.to_csv(os.path.join(RESULT_DIR, '表格_四模型评估对比.csv'), index=False, encoding='utf-8-sig', float_format='%.4f')
    
    log_and_print("\n模型评估对比表：")
    log_and_print(df_comparison.to_string())
    log_and_print("\n问题一求解完成")
    log_file.close()

if __name__ == "__main__":
    run_q1_analysis()
# Out:
# 数据加载与预处理
# 原始数据 998行。
# 剔除离群值和缺失值后，最终分析集共 962行。
#
# 开始变量相关性分析
#           变量对  皮尔逊相关系数(r)  Pearson P值  斯皮尔曼相关系数(rho)  Spearman P值
# 0   Y浓度 vs GW    0.108728    0.000730       0.085063     0.008298
# 1  Y浓度 vs BMI   -0.153145    0.000002      -0.132095     0.000040
#
# 开始模型筛选与拟合
#
# 执行最优子集搜索
# 候选预测因子 (9个): ['GW', 'I(GW**2)', 'I(GW**3)', 'BMI', 'I(BMI**2)', 'I(BMI**3)', 'GW:BMI', 'I(GW**2):BMI', 'GW:I(BMI**2)']
#   - 1个变量的最优组合BIC: -3971.03
#   - 2个变量的最优组合BIC: -3982.50
#   - 3个变量的最优组合BIC: -3981.83
#   - 4个变量的最优组合BIC: -3987.40
#   - 5个变量的最优组合BIC: -3986.56
#   - 6个变量的最优组合BIC: -3981.51
#   - 7个变量的最优组合BIC: -3974.73
#   - 8个变量的最优组合BIC: -3967.89
#   - 9个变量的最优组合BIC: -3961.02
#   - 测试候选模型 1/9...
#   - 测试候选模型 2/9...
#   - 测试候选模型 3/9...
#   - 测试候选模型 4/9...
#   - 测试候选模型 5/9...
#   - 测试候选模型 6/9...
#   - 测试候选模型 7/9...
#   - 测试候选模型 8/9...
#   - 测试候选模型 9/9...
#
# ...
# M4最优子集搜索完成 (耗时: 11.48 秒)
# 最终M4固定效应公式: Y染色体浓度 ~ GW + I(GW**2) + I(GW**3) + I(BMI**3)
# M4的BIC值: -4567.1856
# ...
#
# M1-M3: 拟合基准模型
# ...

# %%
import pandas as pd
import numpy as np
import os
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.lines import Line2D

#调色板定义
PALETTE = {
    "outlier_hist": "#d42424",      #剔除数据
    "kept_hist": "#FF831D",         #保留数据
    "m1_line": "#3544EC",           #M1模型
    "m4_line": "#e76f51",           #M4模型
    "individual_lines": "#4C2A85",  #个体趋势
    "eda_line_gw": "#6BC62F",       #孕周趋势
    "eda_line_bmi": "#5E8FFB",      #BMI趋势
}

#渐变色图定义
CMAPS = {
    "eda_gw": "Greens",              # 孕周散点
    "eda_bmi": "Blues",              # BMI散点
    "model_compare": "coolwarm",     # 模型对比图散点
    "final_model": "magma_r"         # 最终模型图散点
}

def setup_plot_style():
    plt.rcParams['font.sans-serif'] = ['SimHei']
    plt.rcParams['axes.unicode_minus'] = False
    sns.set_style("whitegrid", {"font.sans-serif": ['SimHei', 'Arial']})

#各图表绘制
def plot_outlier_distribution(full_df, clean_df, save_path):
    #多变量离群点剔除过程直方图
    plt.figure(figsize=(12, 7))
    sns.histplot(
        data=full_df, x='Y染色体浓度', color=PALETTE['outlier_hist'],
        kde=False, label=f'所有数据 (n={len(full_df)})', alpha=0.6
    )
    sns.histplot(
        data=clean_df, x='Y染色体浓度', color=PALETTE['kept_hist'],
        kde=True, label=f'保留的数据 (n={len(clean_df)})', alpha=1.0, linewidth=1
    )
    plt.xlabel('Y染色体浓度', fontsize=18)
    plt.ylabel('频数', fontsize=18)
    plt.xticks(fontsize=14); plt.yticks(fontsize=14)
    plt.legend(fontsize=16, loc='upper right')
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.show()

def plot_eda_scatters(df, save_path):
    #GW, BMI与Y浓度的探索性散点图
    fig, axes = plt.subplots(1, 2, figsize=(14, 7), sharey=True)
    vars_to_plot = [
        ('GW', '孕周 (周)', CMAPS['eda_gw'], PALETTE['eda_line_gw']),
        ('BMI', '孕妇BMI', CMAPS['eda_bmi'], PALETTE['eda_line_bmi'])
    ]
    for i, (var, label, cmap, line_color) in enumerate(vars_to_plot):
        ax = axes[i]
        sc = ax.scatter(x=df[var], y=df['Y染色体浓度'], c=df['Y染色体浓度'], 
                        cmap=cmap, alpha=0.6, s=80)
        cbar = fig.colorbar(sc, ax=ax, fraction=0.046, pad=0.04)
        cbar.ax.tick_params(labelsize=14)
        sns.regplot(data=df, x=var, y='Y染色体浓度', ax=ax, scatter=False,
                    line_kws={'color': line_color, 'linewidth': 3, 'alpha': 0.8},
                    lowess=True, ci=95)
        ax.set_xlabel(label, fontsize=18)
        ax.tick_params(axis='both', labelsize=14)
    axes[0].set_ylabel('Y染色体浓度', fontsize=18)
    plt.tight_layout()
    fig.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.show()

def plot_model_comparison(df, m1, m4, save_path):
    #M1与M4模型拟合效果的对比图
    plt.figure(figsize=(14, 9))
    sc = plt.scatter(x=df['GW'], y=df['Y染色体浓度'], c=df['Y染色体浓度'],
                     cmap=CMAPS['model_compare'], alpha=0.3, s=80)
    cbar = plt.colorbar(sc)
    cbar.ax.tick_params(labelsize=14)
    
    gw_range = np.linspace(df['GW'].min(), df['GW'].max(), 200)
    plot_data = pd.DataFrame({'GW': gw_range, 'BMI': df['BMI'].mean()})
    
    plt.plot(plot_data['GW'], m1.predict(plot_data), color=PALETTE['m1_line'], 
             linewidth=2.5, linestyle='--', label='M1: 简单线性模型')
    plt.plot(plot_data['GW'], m4.predict(plot_data), color=PALETTE['m4_line'], 
             linewidth=2.5, linestyle='-', label='M4: 最终非线性模型 (固定效应)')
    
    plt.xlabel('孕周 (周)', fontsize=18); plt.ylabel('Y染色体浓度', fontsize=18)
    plt.xticks(fontsize=14); plt.yticks(fontsize=14)
    plt.legend(fontsize=16, loc='upper left')
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.show()

def plot_final_model_M4(df, m4, save_path):
    #M4的固定效应与随机效应可视化图
    plt.figure(figsize=(14, 9))
    sc = plt.scatter(x=df['GW'], y=df['Y染色体浓度'], c=df['Y染色体浓度'],
                     cmap=CMAPS['final_model'], alpha=0.3, s=80)
    cbar = plt.colorbar(sc)
    cbar.ax.tick_params(labelsize=14)
    
    #绘制总体平均趋势
    gw_range_pop = np.linspace(df['GW'].min(), df['GW'].max(), 200)
    plot_data_pop = pd.DataFrame({'GW': gw_range_pop, 'BMI': df['BMI'].mean()})
    plt.plot(plot_data_pop['GW'], m4.predict(plot_data_pop), 
             color=PALETTE['m4_line'], linewidth=5, linestyle='-')
    
    #绘制个体趋势样本
    random_effects = m4.random_effects
    np.random.seed(42)#采用常用随机种子
    random_subjects = np.random.choice(df['孕妇代码'].unique(), 30, replace=False)

    for subject in random_subjects:
        subj_data = df[df['孕妇代码'] == subject]
        if len(subj_data) < 2: continue # 至少需要两个点来定义趋势范围
        
        re = random_effects[subject]
        intercept_re, slope_re = re.get('Group', 0), re.get('GW', 0)
        
        gw_range_ind = np.linspace(subj_data['GW'].min(), subj_data['GW'].max(), 100)
        plot_data_ind = pd.DataFrame({'GW': gw_range_ind, 'BMI': subj_data['BMI'].mean()})
        
        pred_fixed = m4.predict(plot_data_ind)
        pred_individual = pred_fixed + intercept_re + slope_re * plot_data_ind['GW']
        plt.plot(plot_data_ind['GW'], pred_individual, color=PALETTE['individual_lines'],
                 linewidth=1.5, linestyle='--', alpha=0.6)
    
    #图例
    custom_lines = [
        Line2D([0], [0], marker='o', color='w', markerfacecolor='gray', markersize=10),
        Line2D([0], [0], color=PALETTE['m4_line'], lw=4),
        Line2D([0], [0], color=PALETTE['individual_lines'], lw=2, ls='--')
    ]
    plt.legend(handles=custom_lines, labels=['观测数据', '总体平均趋势', '个体趋势样本'],
               fontsize=16, loc='upper left')
    plt.xlabel('孕周 (周)', fontsize=18); plt.ylabel('Y染色体浓度', fontsize=18)
    plt.xticks(fontsize=14); plt.yticks(fontsize=14)
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.show()

#执行函数
def generate_visualizations_q1():
    RESULT_DIR = 'Result' 
    IMAGE_DIR = 'Result'
    os.makedirs(IMAGE_DIR, exist_ok=True)
    setup_plot_style()

    print("\n数据加载与模型重现")
    model_data = pd.read_csv(os.path.join(RESULT_DIR, '表格_最终建模数据.csv'))
    full_data = pd.read_csv('../../Data/0/男胎_预处理后数据.csv') # 从原始路径加载完整数据

    # 仅重现绘图所需的模型
    m1_linear = smf.ols('Y染色体浓度 ~ GW + BMI', data=model_data).fit()
    formula_m4 = 'Y染色体浓度 ~ GW + I(GW**2) + I(GW**3) + I(BMI**3)'
    m4_final = smf.mixedlm(formula_m4, data=model_data, groups='孕妇代码', re_formula='~ GW').fit(reml=False, method='cg')
    print("M1和M4模型已重现。")

    print("\n开始生成可视化图表 ---")
    plot_outlier_distribution(full_data, model_data, os.path.join(IMAGE_DIR, '图1_离群点剔除过程.png'))
    plot_eda_scatters(model_data, os.path.join(IMAGE_DIR, '图2_核心变量探索性分析.png'))
    plot_model_comparison(model_data, m1_linear, m4_final, os.path.join(IMAGE_DIR, '图3_模型拟合效果对比.png'))
    plot_final_model_M4(model_data, m4_final, os.path.join(IMAGE_DIR, '图4_最终模型M4可视化.png'))

    print("\n可视化完成 ---")

if __name__ == "__main__":
    generate_visualizations_q1()
# Out:
# 数据加载与模型重现
# M1和M4模型已重现。
#
# 开始生成可视化图表 ---
# 可视化完成 ---
