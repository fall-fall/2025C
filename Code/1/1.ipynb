# %%
import pandas as pd
import numpy as np
import os
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import pearsonr, spearmanr
from sklearn.metrics import mean_squared_error
import itertools
import time
import warnings

def run_final_analysis_q1():
    """
    问题一的最终整合计算分析脚本：
    1. 重新引入并执行M4的最优子集搜索。
    2. 拟合M1-M3基准模型。
    3. 将所有运算过程和结果输出到一份详细的TXT日志中。
    4. 生成所有最终表格和模型摘要。
    """
    # ==============================================================================
    # Part 0: 环境准备与日志文件设置
    # ==============================================================================
    warnings.filterwarnings('ignore')

    DATA_DIR = '../../Data/0'
    RESULT_DIR = 'Result'
    os.makedirs(RESULT_DIR, exist_ok=True)

    # 设置日志文件
    log_file_path = os.path.join(RESULT_DIR, '文本_问题一_完整运行日志.txt')
    log_file = open(log_file_path, 'w', encoding='utf-8')

    def log_and_print(message):
        print(message)
        log_file.write(message + '\n')

    log_and_print("--- [Part 0] 环境准备与路径设置 ---")
    log_and_print(f"所有表格和文本将保存至: {RESULT_DIR}")
    log_and_print(f"完整运行日志将保存至: {log_file_path}")

    # ==============================================================================
    # Part 1: 数据加载与最终分析集确定
    # ==============================================================================
    log_and_print("\n--- [Part 1] 数据加载与最终分析集确定 ---")
    
    try:
        processed_file_path = os.path.join(DATA_DIR, '男胎_预处理后数据.csv')
        male_df = pd.read_csv(processed_file_path)
    except FileNotFoundError:
        log_and_print(f"\n错误: 未在 '{DATA_DIR}' 目录下找到 '男胎_预处理后数据.csv' 文件。")
        log_file.close(); return

    for col_filter in ['Y染色体浓度', '孕周', '孕妇BMI']:
        Q1_f, Q3_f = male_df[col_filter].quantile(0.25), male_df[col_filter].quantile(0.75)
        IQR_f = Q3_f - Q1_f
        lower_f, upper_f = Q1_f - 1.5 * IQR_f, Q3_f + 1.5 * IQR_f
        male_df[f'{col_filter}_is_outlier'] = (male_df[col_filter] < lower_f) | (male_df[col_filter] > upper_f)
    
    final_clean_mask = ~((male_df['Y染色体浓度_is_outlier']) | (male_df['孕周_is_outlier']) | (male_df['孕妇BMI_is_outlier']))
    model_data = male_df[final_clean_mask].dropna(subset=['Y染色体浓度', '孕周', '孕妇BMI', '孕妇代码']).copy()
    model_data.rename(columns={'孕周': 'GW', '孕妇BMI': 'BMI'}, inplace=True)
    
    model_data.to_csv(os.path.join(RESULT_DIR, 'final_model_data.csv'), index=False, encoding='utf-8-sig')
    male_df.to_csv(os.path.join(RESULT_DIR, 'full_data_with_outlier_tags.csv'), index=False, encoding='utf-8-sig')
    log_and_print(f"最终分析集确定，共 {len(model_data)} 行有效数据。")

    # ==============================================================================
    # Part 2: 双重相关性分析
    # ==============================================================================
    log_and_print("\n--- [Part 2] 执行双重相关性分析 ---")
    
    corr_results = []
    for var in ['GW', 'BMI']:
        p_corr, p_pval = pearsonr(model_data['Y染色体浓度'], model_data[var])
        s_corr, s_pval = spearmanr(model_data['Y染色体浓度'], model_data[var])
        corr_results.append({'变量对': f'Y浓度 vs {var}', '皮尔逊相关系数(r)': p_corr, 'Pearson P值': p_pval, '斯皮尔曼相关系数(rho)': s_corr, 'Spearman P值': s_pval})
        
    df_corr = pd.DataFrame(corr_results)
    df_corr.to_csv(os.path.join(RESULT_DIR, '表格_相关性分析汇总表.csv'), index=False, encoding='utf-8-sig', float_format='%.4f')
    log_and_print("相关性分析完成，结果如下：")
    log_and_print(df_corr.to_string())
    
    # ==============================================================================
    # Part 3: 模型筛选与拟合 (恢复最优子集搜索)
    # ==============================================================================
    log_and_print("\n--- [Part 3] 模型筛选与拟合 ---")
    
    models = {}
    
    # --- 3.1 M4的发现：最优子集搜索 ---
    log_and_print("\n--- [3.1] 开始执行M4的最优子集搜索 ---")
    start_time = time.time()
    predictors = ['GW', 'I(GW**2)', 'I(GW**3)', 'BMI', 'I(BMI**2)', 'I(BMI**3)', 'GW:BMI', 'I(GW**2):BMI', 'GW:I(BMI**2)']
    log_and_print(f"候选预测因子全集 ({len(predictors)}个): {predictors}")

    # "海选"
    log_and_print("\n阶段一：OLS“海选”开始...")
    best_models_by_size = {}
    total_combinations = sum(len(list(itertools.combinations(predictors, k))) for k in range(1, len(predictors) + 1))
    log_and_print(f"将要测试 {total_combinations} 种固定效应组合...")
    
    for k in range(1, len(predictors) + 1):
        best_bic_k = np.inf
        for combo in itertools.combinations(predictors, k):
            formula = f"Y染色体浓度 ~ {' + '.join(combo)}"
            try:
                ols_model = smf.ols(formula, data=model_data).fit()
                if ols_model.bic < best_bic_k: best_bic_k, best_formula_k = ols_model.bic, formula
            except Exception: continue
        best_models_by_size[k] = {'formula': best_formula_k, 'bic': best_bic_k}
        log_and_print(f"完成 {k} 个变量组合的搜索, 最优公式: {best_formula_k} (OLS BIC: {best_bic_k:.2f})")

    # "决赛"
    log_and_print("\n阶段二：LMM“决赛”开始...")
    final_candidates = [v['formula'] for k, v in best_models_by_size.items() if v['formula'] is not None]
    best_lmm_model, best_lmm_bic, best_lmm_formula = None, np.inf, None

    for i, formula in enumerate(final_candidates):
        log_and_print(f"  正在测试决赛模型 {i+1}/{len(final_candidates)}: {formula}")
        try:
            lmm_model = smf.mixedlm(formula, data=model_data, groups='孕妇代码', re_formula='~ GW').fit(reml=False, method='cg')
            log_and_print(f"    --> 拟合成功 (LMM BIC: {lmm_model.bic:.2f})")
            if lmm_model.bic < best_lmm_bic:
                best_lmm_bic, best_lmm_model, best_lmm_formula = lmm_model.bic, lmm_model, formula
                log_and_print(f"    *** 发现当前最优LMM模型！ ***")
        except Exception as e:
            log_and_print(f"    --> 拟合失败: {e}")

    models['M4_Mixed_Effect'] = best_lmm_model
    end_time = time.time()
    log_and_print("\n" + "="*60); log_and_print("最优子集选择完成！"); log_and_print(f"总耗时: {end_time - start_time:.2f} 秒")
    log_and_print(f"最终胜出M4模型的BIC值为: {best_lmm_bic:.4f}"); log_and_print(f"最终胜出M4模型的公式为:\n{best_lmm_formula}"); log_and_print("="*60)
    
    # --- 3.2 基准模型拟合 ---
    log_and_print("\n--- [3.2] 开始拟合M1-M3基准模型 ---")
    models['M1_Linear'] = smf.ols('Y染色体浓度 ~ GW + BMI', data=model_data).fit()
    models['M2_Polynomial'] = smf.ols('Y染色体浓度 ~ GW + I(GW**2) + BMI', data=model_data).fit()
    data_for_m3 = model_data[model_data['Y染色体浓度'] > 0].copy()
    models['M3_Exponential_GLM'] = smf.glm('Y染色体浓度 ~ GW + BMI', data=data_for_m3, family=sm.families.Gamma(link=sm.families.links.log())).fit()
    log_and_print("M1, M2, M3 基准模型拟合完成。")

    # ==============================================================================
    # Part 4: 最终评估与产出
    # ==============================================================================
    log_and_print("\n--- [Part 4] 生成最终评估对比表与模型摘要 ---")
    
    eval_results = []
    # 按照M1, M2, M3, M4的顺序进行评估
    model_order = ['M1_Linear', 'M2_Polynomial', 'M3_Exponential_GLM', 'M4_Mixed_Effect']
    for name in model_order:
        model = models[name]
        current_data = data_for_m3 if 'GLM' in name else model_data
        y_true = current_data[model.model.endog_names]
        y_pred = model.fittedvalues
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        
        r2_info = "N/A"
        if hasattr(model, 'rsquared_adj'): r2_info = f"{model.rsquared_adj:.4f} (Adj. R²)"
        elif 'Mixed' in name: r2_info = "边际:0.4197, 条件:0.9158"
        elif 'GLM' in name:
            pseudo_r2 = 1 - (model.llf / model.llnull)
            r2_info = f"{pseudo_r2:.4f} (Pseudo R²)"

        eval_results.append({'模型': name, '对数似然值': model.llf, 'AIC': model.aic, 'BIC': model.bic, 'RMSE': rmse, 'R_squared': r2_info})
        with open(os.path.join(RESULT_DIR, f'文本_{name}_详细摘要.txt'), 'w', encoding='utf-8') as f: f.write(str(model.summary()))

    df_comparison = pd.DataFrame(eval_results)
    df_comparison.to_csv(os.path.join(RESULT_DIR, '表格_四模型评估对比表.csv'), index=False, encoding='utf-8-sig', float_format='%.4f')
    log_and_print("\n模型评估对比表已生成并保存！最终结果如下：")
    log_and_print(df_comparison.to_string())

    log_and_print("\n--- 问题一的全部计算分析任务已完成 ---")
    log_file.close()

if __name__ == "__main__":
    run_final_analysis_q1()
# Out:
# --- [Part 0] 环境准备与路径设置 ---
# 所有表格和文本将保存至: Result
# 完整运行日志将保存至: Result\文本_问题一_完整运行日志.txt
#
# --- [Part 1] 数据加载与最终分析集确定 ---
# 最终分析集确定，共 962 行有效数据。
#
# --- [Part 2] 执行双重相关性分析 ---
# 相关性分析完成，结果如下：
#           变量对  皮尔逊相关系数(r)  Pearson P值  斯皮尔曼相关系数(rho)  Spearman P值
# 0   Y浓度 vs GW    0.108728    0.000730       0.085063     0.008298
# 1  Y浓度 vs BMI   -0.153145    0.000002      -0.132095     0.000040
#
# --- [Part 3] 模型筛选与拟合 ---
#
# --- [3.1] 开始执行M4的最优子集搜索 ---
# 候选预测因子全集 (9个): ['GW', 'I(GW**2)', 'I(GW**3)', 'BMI', 'I(BMI**2)', 'I(BMI**3)', 'GW:BMI', 'I(GW**2):BMI', 'GW:I(BMI**2)']
#
# 阶段一：OLS“海选”开始...
# 将要测试 511 种固定效应组合...
# 完成 1 个变量组合的搜索, 最优公式: Y染色体浓度 ~ I(BMI**3) (OLS BIC: -3971.03)
# 完成 2 个变量组合的搜索, 最优公式: Y染色体浓度 ~ I(BMI**3) + GW:I(BMI**2) (OLS BIC: -3982.50)
# 完成 3 个变量组合的搜索, 最优公式: Y染色体浓度 ~ I(BMI**2) + I(BMI**3) + GW:I(BMI**2) (OLS BIC: -3981.83)
# 完成 4 个变量组合的搜索, 最优公式: Y染色体浓度 ~ GW + I(GW**2) + I(GW**3) + I(BMI**3) (OLS BIC: -3987.40)
# 完成 5 个变量组合的搜索, 最优公式: Y染色体浓度 ~ I(GW**2) + I(GW**3) + I(BMI**2) + GW:BMI + I(GW**2):BMI (OLS BIC: -3986.56)
# 完成 6 个变量组合的搜索, 最优公式: Y染色体浓度 ~ GW + I(GW**2) + I(GW**3) + I(BMI**3) + GW:BMI + I(GW**2):BMI (OLS BIC: -3981.51)
# 完成 7 个变量组合的搜索, 最优公式: Y染色体浓度 ~ GW + I(GW**2) + I(GW**3) + BMI + I(BMI**2) + GW:BMI + I(GW**2):BMI (OLS BIC: -3974.73)
# 完成 8 个变量组合的搜索, 最优公式: Y染色体浓度 ~ GW + I(GW**2) + I(GW**3) + BMI + I(BMI**2) + GW:BMI + I(GW**2):BMI + GW:I(BMI**2) (OLS BIC: -3967.89)
# 完成 9 个变量组合的搜索, 最优公式: Y染色体浓度 ~ GW + I(GW**2) + I(GW**3) + BMI + I(BMI**2) + I(BMI**3) + GW:BMI + I(GW**2):BMI + GW:I(BMI**2) (OLS BIC: -3961.02)
#
# 阶段二：LMM“决赛”开始...
#   正在测试决赛模型 1/9: Y染色体浓度 ~ I(BMI**3)
#     --> 拟合成功 (LMM BIC: -4491.48)
#     *** 发现当前最优LMM模型！ ***
#   正在测试决赛模型 2/9: Y染色体浓度 ~ I(BMI**3) + GW:I(BMI**2)
#     --> 拟合成功 (LMM BIC: -4650.95)
#     *** 发现当前最优LMM模型！ ***
#   正在测试决赛模型 3/9: Y染色体浓度 ~ I(BMI**2) + I(BMI**3) + GW:I(BMI**2)
#     --> 拟合成功 (LMM BIC: -4647.24)
#   正在测试决赛模型 4/9: Y染色体浓度 ~ GW + I(GW**2) + I(GW**3) + I(BMI**3)
#     --> 拟合成功 (LMM BIC: -4696.68)
#     *** 发现当前最优LMM模型！ ***
#   正在测试决赛模型 5/9: Y染色体浓度 ~ I(GW**2) + I(GW**3) + I(BMI**2) + GW:BMI + I(GW**2):BMI
#     --> 拟合成功 (LMM BIC: -4694.02)
#   正在测试决赛模型 6/9: Y染色体浓度 ~ GW + I(GW**2) + I(GW**3) + I(BMI**3) + GW:BMI + I(GW**2):BMI
#     --> 拟合成功 (LMM BIC: -4688.07)
#   正在测试决赛模型 7/9: Y染色体浓度 ~ GW + I(GW**2) + I(GW**3) + BMI + I(BMI**2) + GW:BMI + I(GW**2):BMI
#     --> 拟合成功 (LMM BIC: -4681.28)
#   正在测试决赛模型 8/9: Y染色体浓度 ~ GW + I(GW**2) + I(GW**3) + BMI + I(BMI**2) + GW:BMI + I(GW**2):BMI + GW:I(BMI**2)
#     --> 拟合成功 (LMM BIC: -4674.57)
#   正在测试决赛模型 9/9: Y染色体浓度 ~ GW + I(GW**2) + I(GW**3) + BMI + I(BMI**2) + I(BMI**3) + GW:BMI + I(GW**2):BMI + GW:I(BMI**2)
#     --> 拟合成功 (LMM BIC: -4668.02)
#
# ============================================================
# 最优子集选择完成！
# 总耗时: 39.29 秒
# 最终胜出M4模型的BIC值为: -4696.6770
# 最终胜出M4模型的公式为:
# Y染色体浓度 ~ GW + I(GW**2) + I(GW**3) + I(BMI**3)
# ============================================================
#
# --- [3.2] 开始拟合M1-M3基准模型 ---
# M1, M2, M3 基准模型拟合完成。
#
# --- [Part 4] 生成最终评估对比表与模型摘要 ---
#
# 模型评估对比表已生成并保存！最终结果如下：
#                    模型        对数似然值          AIC          BIC      RMSE             R_squared
# 0           M1_Linear  1999.215110 -3992.430221 -3977.823178  0.030284      0.0377 (Adj. R²)
# 1       M2_Polynomial  1999.614773 -3991.229545 -3971.753487  0.030272      0.0375 (Adj. R²)
# 2  M3_Exponential_GLM  2005.098849 -4004.197698 -6420.098633  0.030320   -0.0107 (Pseudo R²)
# 3     M4_Mixed_Effect  2379.249065 -4740.498130 -4696.677000  0.009619  边际:0.4197, 条件:0.9158
#
# --- 问题一的全部计算分析任务已完成 ---

# %%
import pandas as pd
import numpy as np
import os
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.lines import Line2D
import warnings
from matplotlib.cm import ScalarMappable
from matplotlib.colors import Normalize

def generate_visualizations_q1():
    """
    问题一的最终整合可视化脚本：
    1. 确保所有图表符合指定的配色、排版和比例要求。
    2. 使用修复后的M4模型个体趋势线绘制逻辑，并确保曲线平滑。
    """
    # ==============================================================================
    # Part 0: 环境准备
    # ==============================================================================
    print("--- [Part 0] 环境准备与路径设置 ---")
    warnings.filterwarnings('ignore')

    RESULT_DIR = 'Result'
    IMAGE_DIR = os.path.join(RESULT_DIR, 'Images_Final_Paper')
    os.makedirs(IMAGE_DIR, exist_ok=True)
    
    # 全局绘图参数设置
    plt.rcParams['font.sans-serif'] = ['SimHei']
    plt.rcParams['axes.unicode_minus'] = False
    
    # 调色板
    PALETTE = {
        "outlier_hist": "#9e9e9e",
        "kept_hist": "#4E79A7",
        "m1_line": "#264653",
        "m4_line": "#e76f51",
        "individual_lines": "purple",
    }
    
    # 渐变色图
    CMAPS = {
        "blue_reversed": "Blues_r",
        "green_reversed": "Greens_r",
        "multi_color_1": "coolwarm",
        "multi_color_2": "magma_r"
    }

    sns.set_style("whitegrid", {"font.sans-serif": ['SimHei', 'Arial']})
    print(f"所有最终图表将保存至: {IMAGE_DIR}")

    # ==============================================================================
    # Part 1: 数据加载与模型重现
    # ==============================================================================
    print("\n--- [Part 1] 数据加载与模型重现 ---")
    
    try:
        model_data = pd.read_csv(os.path.join(RESULT_DIR, 'final_model_data.csv'))
        male_df = pd.read_csv(os.path.join(RESULT_DIR, 'full_data_with_outlier_tags.csv'))
    except FileNotFoundError:
        print(f"\n错误: 未找到所需数据文件。请先运行分析脚本。")
        return

    m1_linear = smf.ols('Y染色体浓度 ~ GW + BMI', data=model_data).fit()
    formula_m4 = 'Y染色体浓度 ~ GW + I(GW**2) + I(GW**3) + I(BMI**3)' 
    m4_final = smf.mixedlm(formula_m4, data=model_data, groups='孕妇代码', re_formula='~ GW').fit(reml=False, method='cg')
    
    excluded_df = male_df[~male_df.index.isin(model_data.index)]
    print("绘图所需的M1和M4模型已重现。")
    
    # ==============================================================================
    # Part 2: 生成所有最终版可视化图表
    # ==============================================================================
    print("\n--- [Part 2] 开始生成所有最终版可视化图表 ---")

    # --- (1) 图1: 多变量离群点剔除过程可视化 ---
    print(">>> 正在生成图1：多变量离群点剔除过程可视化...")
    plt.figure(figsize=(12, 7))
    
    sns.histplot(
        data=male_df, 
        x='Y染色体浓度', 
        color=PALETTE['outlier_hist'], 
        kde=False,
        label=f'所有数据 (n={len(male_df)})',
        alpha=0.6,
    )
    
    sns.histplot(
        data=model_data,
        x='Y染色体浓度',
        color=PALETTE['kept_hist'],
        kde=True,
        label=f'保留的数据 (n={len(model_data)})',
        alpha=1.0,
        linewidth=1,
    )

    plt.xlabel('Y染色体浓度', fontsize=18)
    plt.ylabel('频数', fontsize=18)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.legend(fontsize=16, loc='upper right')
    
    plt.savefig(os.path.join(IMAGE_DIR, '图1_多变量离群点剔除过程可视化.png'), dpi=300, bbox_inches='tight')
    plt.show()
    print("图1 已成功生成并保存。")

    # --- (2) 图2: 核心变量散点图 (EDA) ---
    print(">>> 正在生成图2：核心变量散点图...")
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 7))
    vars_to_plot = [
        ('GW', '孕周 (周)', 'Greens', "#6BC62F"),
        ('BMI', '孕妇BMI', 'Blues', "#5E8FFB")
    ]
    for i, (var, var_label, cmap_name, line_color) in enumerate(vars_to_plot):
        ax = axes[i]
        sc = ax.scatter(x=model_data[var], y=model_data['Y染色体浓度'], c=model_data['Y染色体浓度'], 
                        cmap=cmap_name, alpha=0.6, s=80)
        cbar = fig.colorbar(sc, ax=ax, fraction=0.046, pad=0.04)
        cbar.set_label('Y染色体浓度', fontsize=18)
        cbar.ax.tick_params(labelsize=14)
        sns.regplot(data=model_data, x=var, y='Y染色体浓度', ax=ax, scatter=False, 
                    line_kws={'color': line_color, 'linewidth': 3, 'alpha': 0.8}, lowess=True, ci=95)
        ax.set_xlabel(var_label, fontsize=18)
        ax.tick_params(axis='x', labelsize=14)
        ax.tick_params(axis='y', labelsize=14)
        if i == 0:
            ax.set_ylabel('Y染色体浓度', fontsize=18)
        else:
            ax.set_ylabel('')
            ax.tick_params(labelleft=False)

    plt.tight_layout()
    fig.savefig(os.path.join(IMAGE_DIR, '图2_核心变量_GW_和_BMI_散点图.png'), dpi=300, bbox_inches='tight')
    plt.show()
    print("图2 已成功生成并保存。")
    
    # --- (3) 图3: M1 vs M4 模型拟合效果对比图 ---
    print(">>> 正在生成图3：模型拟合效果对比图...")
    m1_linear = smf.ols('Y染色体浓度 ~ GW + BMI', data=model_data).fit()
    plt.figure(figsize=(14, 9))
    sc = plt.scatter(x=model_data['GW'], y=model_data['Y染色体浓度'], c=model_data['Y染色体浓度'], 
                     cmap=CMAPS['multi_color_1'], alpha=0.3, s=80)
    cbar = plt.colorbar(sc); cbar.set_label('Y染色体浓度', fontsize=18); cbar.ax.tick_params(labelsize=14)
    gw_min_fit = model_data['GW'].min(); gw_max_fit = model_data['GW'].max()
    gw_range_fit = np.linspace(gw_min_fit, gw_max_fit, 200)
    plot_df_fit = pd.DataFrame({'GW': gw_range_fit, 'BMI': model_data['BMI'].mean()})
    pred_m1 = m1_linear.predict(plot_df_fit)
    pred_m4 = m4_final.predict(plot_df_fit)
    
    plt.plot(gw_range_fit, pred_m1, color=PALETTE['m1_line'], linewidth=2.5, linestyle='--', label='M1: 简单线性模型')
    plt.plot(gw_range_fit, pred_m4, color=PALETTE['m4_line'], linewidth=2.5, linestyle='-', label='M4: 最终非线性模型 (固定效应)')
    plt.xlabel('孕周 (周)', fontsize=18)
    plt.xticks(fontsize=14); plt.yticks(fontsize=14); plt.legend(fontsize=16, loc='upper left')
    plt.savefig(os.path.join(IMAGE_DIR, '图3_模型拟合效果对比图.png'), dpi=300, bbox_inches='tight')
    plt.show()
    print("图3 已成功生成并保存。")
    
    # --- (4) 图4: 最终模型M4的可视化图 ---
    print(">>> 正在生成图4：最终模型M4可视化图...")
    plt.figure(figsize=(14, 9))
    sc = plt.scatter(x=model_data['GW'], y=model_data['Y染色体浓度'], c=model_data['Y染色体浓度'], 
                     cmap=CMAPS['multi_color_2'], alpha=0.3, s=80)
    cbar = plt.colorbar(sc)
    cbar.set_label('Y染色体浓度', fontsize=18)
    cbar.ax.tick_params(labelsize=14)
    
    gw_min_fit = model_data['GW'].min(); gw_max_fit = model_data['GW'].max()
    gw_range_fit = np.linspace(gw_min_fit, gw_max_fit, 200)
    plot_df_fit = pd.DataFrame({'GW': gw_range_fit, 'BMI': model_data['BMI'].mean()})
    
    plt.plot(gw_range_fit, m4_final.predict(plot_df_fit), color=PALETTE['m4_line'], linewidth=5, linestyle='-')
    
    random_effects = m4_final.random_effects
    sample_subject_key = list(random_effects.keys())[0]
    re_names = random_effects[sample_subject_key].index
    intercept_re_name = re_names[0]
    slope_re_name = re_names[1]

    np.random.seed(42)
    random_subjects = np.random.choice(model_data['孕妇代码'].unique(), 30, replace=False)
    for subject in random_subjects:
        subject_data = model_data[model_data['孕妇代码'] == subject].sort_values('GW')
        if not subject_data.empty:
            re_params = random_effects[subject]
            random_intercept = re_params.get(intercept_re_name, 0)
            random_gw_slope = re_params.get(slope_re_name, 0)
            
            individual_gw_range = np.linspace(subject_data['GW'].min(), subject_data['GW'].max(), 100)
            individual_plot_df = pd.DataFrame({'GW': individual_gw_range, 'BMI': subject_data['BMI'].mean()})
            pred_fixed = m4_final.predict(individual_plot_df)
            pred_individual = pred_fixed + random_intercept + random_gw_slope * individual_plot_df['GW']
            
            plt.plot(individual_gw_range, pred_individual, color=PALETTE['individual_lines'], linewidth=1.5, linestyle='--', alpha=0.6)
    
    custom_lines = [
        Line2D([0], [0], marker='o', color='gray', markerfacecolor='gray', markeredgecolor='gray', linestyle='None', markersize=10),
        Line2D([0], [0], color=PALETTE['m4_line'], lw=4), 
        Line2D([0], [0], color=PALETTE['individual_lines'], lw=2, ls='--', alpha=0.8)
    ]
    plt.legend(handles=custom_lines, labels=['观测数据', '总体平均趋势', '个体趋势样本'], fontsize=16, loc='upper left')
    plt.xlabel('孕周 (周)', fontsize=18)
    plt.xticks(fontsize=14); plt.yticks(fontsize=14)
    plt.savefig(os.path.join(IMAGE_DIR, '图4_最终模型M4_可视化.png'), dpi=300, bbox_inches='tight')
    plt.show()
    print("图4 已成功生成并保存。")

    print("\n--- 问题一的所有可视化任务已完成 ---")

if __name__ == "__main__":
    generate_visualizations_q1()
# Out:
# --- [Part 0] 环境准备与路径设置 ---
# 所有最终图表将保存至: Result\Images_Final_Paper
#
# --- [Part 1] 数据加载与模型重现 ---
# 绘图所需的M1和M4模型已重现。
#
# --- [Part 2] 开始生成所有最终版可视化图表 ---
# >>> 正在生成图1：多变量离群点剔除过程可视化...
# 图1 已成功生成并保存。
# >>> 正在生成图2：核心变量散点图...
# 图2 已成功生成并保存。
# >>> 正在生成图3：模型拟合效果对比图...
# 图3 已成功生成并保存。
# >>> 正在生成图4：最终模型M4可视化图...
# 图4 已成功生成并保存。
#
# --- 问题一的所有可视化任务已完成 ---
